# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2005

# %% [markdown]
# ## Create conference Item

# %%
year = "2005"
location = "Madrid"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2005"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2005: Madrid"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2005"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2005"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68279207"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/28" ## Needs to be changed
location = " Madrid, Spain, 12-15 September 2005" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2005 International Conference on Dublin Core and Metadata Applications, DC-2005 in  Madrid, Spain, 12-15 September 2005"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Proceedings of the 2005 International Conference on Dublin Core and Metadata Applications, DC-2005 in  Madrid, Spain, 12-15 September 2005"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P4745	Q68279207	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"

# %%
proceedingsQID = "Q68279349"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Presentation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Presentation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/796"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Preface"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Preface"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/797"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"SKOS Core: Simple knowledge organisation for the Web"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"SKOS Core: Simple knowledge organisation for the Web"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/798"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Alistair Miles"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Brian Matthews"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Michael Wilson"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Dan Brickley"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Toward core subject vocabularies for community-oriented subject gateways"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Toward core subject vocabularies for community-oriented subject gateways"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/799"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Wonsook Lee"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Using Dublin Core application profiles to manage diverse metadata dDevelopments"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Using Dublin Core application profiles to manage diverse metadata dDevelopments"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/800"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Robina Clayphan"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Bill Oldroyd"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Was CIMI too early? Dublin Core and Museum Information: metadata as cultural heritage data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Was CIMI too early? Dublin Core and Museum Information: metadata as cultural heritage data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/801"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Liddy Nevile"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Sophie Lissonnet"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"BDNG: A Dublin Core-based architecture for digital libraries"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"BDNG: A Dublin Core-based architecture for digital libraries"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/802"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Edwin Montoya"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Edwin Montoya"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Jorge Giraldo"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Orchestrating metadata enhancement services: Introducing Lenny"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Orchestrating metadata enhancement services: Introducing Lenny"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/803"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Jon Phipps"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Diane I. Hillmann"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Gordon Paynter"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Anonymous Dublin Core profiles for accessible user relationships with resources and services"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Anonymous Dublin Core profiles for accessible user relationships with resources and services"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/804"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Liddy Nevile"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Promoting accessibility by using metadata in the framework of a semantic-web driven CMS"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Promoting accessibility by using metadata in the framework of a semantic-web driven CMS"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/805"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Rocío García-Robles"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Fernando Díaz del Río"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Antón Civit"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Juan Antonio Prieto"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Towards accessible Semantic Web applications"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Towards accessible Semantic Web applications"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/806"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Lourdes Moreno"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Paloma Martínez"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Jesús Contreras"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Richard Benjamin"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Retrieval of Italian legal literature: a case of semantic search using legal vocabulary"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Retrieval of Italian legal literature: a case of semantic search using legal vocabulary"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/807"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Enrico Francesconi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Ginevra Peruginelli"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Growing vocabularies for plant identification and scientific learning"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Growing vocabularies for plant identification and scientific learning"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/808"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Jane Greenberg"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"P. Bryan Heidorn"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Stephen Seiberling"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Alan S. Weakley"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"A framework for the standardized description of handwritten annotations"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"A framework for the standardized description of handwritten annotations"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/809"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Marcel Götze"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Thesauri managing and software agents: A proposed architecture"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Thesauri managing and software agents: A proposed architecture"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/810"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"José Ramón Pérez Agüera"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Rodrigo Sánchez Jiménez"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Using controlled vocabularies to manage resource relationships: The KMODDL experience"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Using controlled vocabularies to manage resource relationships: The KMODDL experience"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/811"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Martin Kurth"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Greg Nehler"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Rick Silterra"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Use of Dublin Core metadata for describing and retrieving digital journals"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Use of Dublin Core metadata for describing and retrieving digital journals"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/812"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Assumpció Estivill"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Ernest Abadal"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Jorge Franganillo"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Jesús Gascón"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"J. M. Rodríguez Gairín"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Use of the MPEG-7 standard as metadata framework for a location scouting system -- An evaluation study"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Use of the MPEG-7 standard as metadata framework for a location scouting system -- An evaluation study"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/813"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Valérie Gouaillier"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Langis Gagnon"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Sylvain Paquette"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Philippe Poullaouec-Gonidec"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Model of metadata (crosswalk) on the Iberoamerican and Caribbean Virtual Library"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Model of metadata (crosswalk) on the Iberoamerican and Caribbean Virtual Library"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/814"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Javier Solorio Lagunas"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Lourdes Feria Basurto"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Decentralized metadata development for open B2B electronic business"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Decentralized metadata development for open B2B electronic business"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/815"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Fred van Blommestein"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Use of learning object vocabulary in GEM queries"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Use of learning object vocabulary in GEM queries"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/816"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Jian Qin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Javier Calzada Prado"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Metadata at the Library of the National Congress of Chile: a multidisciplinary experience"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Metadata at the Library of the National Congress of Chile: a multidisciplinary experience"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/817"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"María Angélica Fuentes Martínez"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Informational resources of Portal Cuba.cu. Description with metadata Dublin Core format"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Informational resources of Portal Cuba.cu. Description with metadata Dublin Core format"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/818"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Isabel Daudinot Founier"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"A common vocabulary to facilitate the exchange of web accessibility evaluation results"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"A common vocabulary to facilitate the exchange of web accessibility evaluation results"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/819"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Shadi Abou-Zahra"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"On the use of existing upper ontologies as a metadata integration mechanism"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"On the use of existing upper ontologies as a metadata integration mechanism"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/820"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Miguel-Angel Sicilia"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"A hierarchical one-to-one mapping solution for semantic interoperability"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"A hierarchical one-to-one mapping solution for semantic interoperability"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/821"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"David Portolés-Rodríguez"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Rafael Tolosana-Calasanz"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Javier Nogueras-Iso"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Rodolfo Rioja"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Pedro R. Muro-Medrano"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Javier Zarazaga-Soria"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Quatro -- a metadata platform for trustmarks"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Quatro -- a metadata platform for trustmarks"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/822"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Phil Archer"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Web services for genre vocabularies"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Web services for genre vocabularies"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/823"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Eric Childress"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Andrew Houghton"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Diane Vizine-Goetz"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Automating multilingual metadata vocabularies"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Automating multilingual metadata vocabularies"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/824"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Alejandro Bia"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Juan Malonda"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Jaime Gómez"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"A tool for collaborative ontology development for the Semantic Web"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"A tool for collaborative ontology development for the Semantic Web"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/825"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Arttu Valo"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Eero Hyvönen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Ville Komulainen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Application of the Dublin Core format for automatic metadata generation and extraction"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Application of the Dublin Core format for automatic metadata generation and extraction"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/826"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Ernesto Giralt Hernández"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Joan Marc Piulachs"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Finnish National Ontologies for the Semantic Web -- Towards a Content and Service Infrastructure"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Finnish National Ontologies for the Semantic Web -- Towards a Content and Service Infrastructure"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/827"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Eero Hyvönen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Arttu Valo"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Ville Komulainen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Katri Seppälä"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Tomi Kauppinen"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Tuukka Ruotsalo"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Mirva Salminen"	P1545	"7"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Anu Ylisalmi"	P1545	"8"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Metadata for improving dynamic tourist packages"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Metadata for improving dynamic tourist packages"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/828"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Esteve Lladó"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Idoia Murua"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Bel Llodrà"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"MarcOnt -- Integration ontology for bibliographic description formats"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"MarcOnt -- Integration ontology for bibliographic description formats"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/829"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Sebastian Ryszard Kruk"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Marcin Synak"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Kerstin Zimmermann"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"SEARCHY: A metasearch engine for heterogeneous sources in distributed environments"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"SEARCHY: A metasearch engine for heterogeneous sources in distributed environments"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/830"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"David F. Barrero"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"M. Dolores R-Moreno"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Oscar García"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Angel Moreno"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"Towards terminology services: Experiences with a pilot web service thesaurus browser"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"Towards terminology services: Experiences with a pilot web service thesaurus browser"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/831"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Douglas Tudhope"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P2093	"Ceri Binding"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"SKOS and the ontogenesis of vocabularies"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"SKOS and the ontogenesis of vocabularies"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/832"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Joseph T. Tennis"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# CREATE
# LAST	Len	"The Microsoft profiling taxonomy"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1476	en:"The Microsoft profiling taxonomy"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/833"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
# LAST	P1433	Q68279349	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
#
# LAST	P2093	"Amy Sweigert"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/28"
