# %%
# !pip3 install bs4
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# ...
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2016

# %%
url = 'https://dcpapers.dublincore.org/pubs/issue/view/171'
page = requests.get(url).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
for article in table:
    title = article.find('div', {'class': 'tocTitle'})
    print("CREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", ""))
    print("LAST\tDen\t\"conference paper")
    print("LAST\tP31\tQ23927052\tS854\t\"https://dcpapers.dublincore.org/pubs/issue/view/171\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\"https://dcpapers.dublincore.org/pubs/issue/view/171\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\"https://dcpapers.dublincore.org/pubs/issue/view/171\"")
    print("LAST\tP1433\tQ59262206\tS854\t\"https://dcpapers.dublincore.org/pubs/issue/view/171\"")
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\"https://dcpapers.dublincore.org/pubs/issue/view/171\"")
                          
#print(table)


#print(len(table))
# Out:
# CREATE
# LAST	Len	"Committees
# LAST	Den	"conference paper
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/171"
# LAST	P1476	en:"Committees"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/171"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3819"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/171"
# LAST	P1433	Q59262206	S854	"https://dcpapers.dublincore.org/pubs/issue/view/171"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/171"
# CREATE
# LAST	Len	"The British National Bibliography: Who Uses Our Linked                    Data?
# LAST	Den	"conference paper
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/171"
# LAST	P1476	en:"The British National Bibliography: Who Uses Our Linked                    Data?"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/171"
# ...

# %% [markdown]
# # Proceedings 2017

# %%
print("CREATE")
print("LAST\tLen\t\"DC-2017\"")
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-2017: Washington\"")
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-2017\"\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/2016/\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2017"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2017: Washington"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2017"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2016/"	S854	"https://www.dublincore.org/conferences/"

# %% [markdown]
# Item created: Q68181388

# %% [markdown]
# ## create item for the proceedings

# %%
print("CREATE")
print("LAST\tLen\t\"Proceedings of the 2017 International Conference on Dublin Core and Metadata Applications, DC-2017 in Washington, D.C., USA, 26-29 October 2017\"")
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\"https://dcpapers.dublincore.org/pubs/issue/view/172\"")
print("LAST\tP1476\ten:\"Proceedings of the 2017 International Conference on Dublin Core and Metadata Applications, DC-2017 in Washington, D.C., USA, 26-29 October 2017\"")
print("LAST\tP953\t\"https://dcpapers.dublincore.org/pubs/issue/view/172\"")
print("LAST\tP4745\tQ68181388\tS854\t\"https://dcpapers.dublincore.org/pubs/issue/view/172\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2017 International Conference on Dublin Core and Metadata Applications, DC-2017 in Washington, D.C., USA, 26-29 October 2017"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"
# LAST	P1476	en:"Proceedings of the 2017 International Conference on Dublin Core and Metadata Applications, DC-2017 in Washington, D.C., USA, 26-29 October 2017"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/172"
# LAST	P4745	Q68181388	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"

# %% [markdown]
# Item created: Q68181874

# %%
url = 'https://dcpapers.dublincore.org/pubs/issue/view/172'
page = requests.get(url).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
for article in table:
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+url+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+url+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+url+"\"")
    print("LAST\tP1433\tQ68181874\tS854\t\""+url+"\"") ## Need to change with Qid above
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+url+"\"")
# Out:
# CREATE
# LAST	Len	"Committees"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"
# LAST	P1476	en:"Committees"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3848"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"
# LAST	P1433	Q68181874	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"
#
# CREATE
# LAST	Len	"'More Than What It Seems': How Critical Theory, Popular Engagement and Apps Like Tinder Can Help Us Reframe Metadata and Its Consequences"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/172"
# ...

# %% [markdown]
# # Procedings 2018

# %%
print("CREATE")
print("LAST\tLen\t\"DC-2018\"")     ## Need to be changed
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-2018: Porto\"") ## Need to be changed
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-2018\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Need to be changed
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/2018/\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Need to be changed
# Out:
# CREATE
# LAST	Len	"DC-2018"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2018: Porto"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2018"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2018/"	S854	"https://www.dublincore.org/conferences/"

# %% [markdown]
# Item created: Q68183376

# %% [markdown]
# # Create item for proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/177"
print("CREATE")
print("LAST\tLen\t\"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2018 in Porto, September 10-13, 2018\"")  ## Needs to be changed
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2018 in Porto, September 10-13, 2018\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\tQ68181388\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2018 in Porto, September 10-13, 2018"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# LAST	P1476	en:"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2018 in Porto, September 10-13, 2018"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# LAST	P4745	Q68181388	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"

# %% [markdown]
# Item created: Q68183803

# %%
url = 'https://dcpapers.dublincore.org/pubs/issue/view/177' ## Needs to be changed
page = requests.get(url).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
for article in table:
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+url+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+url+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+url+"\"")
    print("LAST\tP1433\tQ68183803\tS854\t\""+url+"\"") ## Need to change with Qid above
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+url+"\"")
# Out:
# CREATE
# LAST	Len	"Chairs' Welcoming and Committees"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# LAST	P1476	en:"Chairs' Welcoming and Committees"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3962"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# LAST	P1433	Q68183803	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
#
# CREATE
# LAST	Len	"An Approach to Enabling RDF Data in Querying to Invoke REST API for Complex Calculating"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# LAST	P1476	en:"An Approach to Enabling RDF Data in Querying to Invoke REST API for Complex Calculating"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/177"
# ...

# %% [markdown]
# # Proceedings 2015

# %% [markdown]
# ## Create conference Item

# %%
print("CREATE")
print("LAST\tLen\t\"DC-2015\"")     ## Need to be changed
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-2015: São Paulo\"") ## Need to be changed
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-2015\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Need to be changed
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/2015\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Need to be changed
# Out:
# CREATE
# LAST	Len	"DC-2015"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2015: São Paulo"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2015"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2015"	S854	"https://www.dublincore.org/conferences/"

# %% [markdown]
# Item created: Q68204967

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/168"
print("CREATE")
print("LAST\tLen\t\"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2015 in São Paulo, Brazil, 1-4 September 2015\"")  ## Needs to be changed
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2015 in São Paulo, Brazil, 1-4 September 2015\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\tQ68204967\tS854\t\""+referenceurl+"\"") # Needs to be changed
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2015 in São Paulo, Brazil, 1-4 September 2015"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# LAST	P1476	en:"Proceedings of the 2018 International Conference on Dublin Core and Metadata Applications, DC-2015 in São Paulo, Brazil, 1-4 September 2015"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# LAST	P4745	Q68204967	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"

# %% [markdown]
# Item Created: Q68205265

# %% [markdown]
# ## Papers

# %%
url = 'https://dcpapers.dublincore.org/pubs/issue/view/168' ## Needs to be changed
page = requests.get(url).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
for article in table:
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+url+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+url+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+url+"\"")
    print("LAST\tP1433\tQ68205265\tS854\t\""+url+"\"") ## Need to change with Qid above
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+url+"\"")
# Out:
# CREATE
# LAST	Len	"Introductions and Committees"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# LAST	P1476	en:"Introductions and Committees"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3757"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# LAST	P1433	Q68205265	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
#
# CREATE
# LAST	Len	"MOD: Metadata for Ontology Description and Publication"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# LAST	P1476	en:"MOD: Metadata for Ontology Description and Publication"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/168"
# ...
