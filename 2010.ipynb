# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2010

# %% [markdown]
# ## Create conference Item

# %%
year = "2010"
location = "Pittsburgh"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\""+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2010"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2010: Pittsburgh"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"2010"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2010"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68240811"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/35" ## Needs to be changed
location = "Pittsburgh, Pennsylvania, USA 20-22 October 2010" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2010 International Conference on Dublin Core and Metadata Applications, DC-2010 in Pittsburgh, Pennsylvania, USA 20-22 October 2010"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Proceedings of the 2010 International Conference on Dublin Core and Metadata Applications, DC-2010 in Pittsburgh, Pennsylvania, USA 20-22 October 2010"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P4745	Q68240811	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"

# %%
proceedingsQID = "Q68241000"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Building blocks of metadata: What can we learn from Lego™?"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Building blocks of metadata: What can we learn from Lego™?"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1041"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Emma Tonkin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Andrew Hewson"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Visualizing Metadata for Environmental Datasets"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Visualizing Metadata for Environmental Datasets"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1018"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Sherry Koshman"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"FRBR: A Generalized Approach to Dublin Core Application Profiles"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"FRBR: A Generalized Approach to Dublin Core Application Profiles"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1024"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Maja Zumer"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Marcia Lei Zeng"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Athena Salaba"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Enhancing Interoperability of FRBR-Based Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Enhancing Interoperability of FRBR-Based Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1037"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Jenn Riley"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Moving Library Metadata Toward Linked Data:  Opportunities Provided by the eXtensible Catalog"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Moving Library Metadata Toward Linked Data:  Opportunities Provided by the eXtensible Catalog"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1010"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Jennifer B. Bowen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Celebrating 10 Years of Government of Canada Metadata Standards"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Celebrating 10 Years of Government of Canada Metadata Standards"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1046"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Margaret Devey"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Marie-Claude Côté"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Leigh Bain"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Lynne McAvoy"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Extending RSS to Meet Central Bank Needs"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Extending RSS to Meet Central Bank Needs"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1005"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Paul Asman"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"San Cannon"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Christine Sommo"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Linking Entities in Scientific Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Linking Entities in Scientific Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1013"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Jian Qin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Miao Chen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Xiaozhong Liu"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Andrea Kathleen Wiggins"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"From records to streams: Merging library and publisher metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"From records to streams: Merging library and publisher metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1033"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Carol Jean Godby"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"The One-To-One Principle: Challenges in Current Practice"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"The One-To-One Principle: Challenges in Current Practice"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1043"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Steven J. Miller"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Better Guidelines, Better Functionality: How Metadata Supports the Cycle of System Improvement at UNT"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Better Guidelines, Better Functionality: How Metadata Supports the Cycle of System Improvement at UNT"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1004"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Hannah Tarver"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Building Metadata Application Framework for Chinese Digital Library: A Case Study of National Digital Library of China"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Building Metadata Application Framework for Chinese Digital Library: A Case Study of National Digital Library of China"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1044"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Yunyun Shen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Long Xiao"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Ying Feng"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Use of Community Metadata: Public Policy Research in PolicyArchive"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Use of Community Metadata: Public Policy Research in PolicyArchive"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/997"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Sarah Buchanan"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Creating Metadata Best Practices for CONTENTdm Users"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Creating Metadata Best Practices for CONTENTdm Users"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/996"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Myung-Ja K. Han"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Sheila Bair"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Jason Lee"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"The Case for Implementing Core Descriptive Embedded Metadata at the Smithsonian"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"The Case for Implementing Core Descriptive Embedded Metadata at the Smithsonian"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1009"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Stephanie Ogeneski Christensen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Douglas Donald Dunlop"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"The Question about Questions: Is DC a Good Choice to Address the Challenges of Representation of Clinical Research Questions and Value Sets?"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"The Question about Questions: Is DC a Good Choice to Address the Challenges of Representation of Clinical Research Questions and Value Sets?"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1032"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"James E. Andrews"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Denise Shereff"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Timothy Patrick"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Rachel Richesson"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Metadata for WICRI, a Network of Semantic Wikis for Communities in Research and Innovation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Metadata for WICRI, a Network of Semantic Wikis for Communities in Research and Innovation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1007"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Jacques Ducloy"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Thierry Daunois"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Muriel Foulonneau"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Alice Hermann"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Jean-Charles Lamirel"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Stéphane Sire"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Jean-Pierre Thomesse"	P1545	"7"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Christine Vanoirbeek"	P1545	"8"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"The public library catalogue as a social space: Transaction log analysis of user interaction with social discovery systems."
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"The public library catalogue as a social space: Transaction log analysis of user interaction with social discovery systems."	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/994"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Louise Spiteri"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Laurel Tarulli"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Alyssa Graybeal"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Vocabulary and Taxonomy Issues When Searching Lesbian, Gay, Bisexual and Transgender (LGBT) Health LiteratureT health literature"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Vocabulary and Taxonomy Issues When Searching Lesbian, Gay, Bisexual and Transgender (LGBT) Health LiteratureT health literature"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1002"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Mary Jo Dorsey"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Ellen Detlefsen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Towards a Premodern Manuscript Application Profile"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Towards a Premodern Manuscript Application Profile"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1006"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Sheila Bair"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Susan Steuer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Universal Access to Cultural Heritage Material: The Europeana Resolution Discovery Service for Persistent Identifiers"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Universal Access to Cultural Heritage Material: The Europeana Resolution Discovery Service for Persistent Identifiers"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1008"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Lars G. Svensson"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Bridging End Users’ Terms and AGROVOC Concept Server Vocabularies"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Bridging End Users’ Terms and AGROVOC Concept Server Vocabularies"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1015"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Ahsan Morshed"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Gudrun Johannsen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Johannes Keizer"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Marcia Lei Zeng"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Metadata application profile: Integrating different metadata schemes for cataloguing digital learning material collection at  Biblioteca Francisco Xavier Clavigero, Universidad Iberoamericana Ciudad de México."
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Metadata application profile: Integrating different metadata schemes for cataloguing digital learning material collection at  Biblioteca Francisco Xavier Clavigero, Universidad Iberoamericana Ciudad de México."	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1016"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Alma B Rivera Aguilera"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Magaly Vega Lopez"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Acalia Pozo-Marrero"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Creating Collection-Level Metadata: A TELDAP Case Study"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Creating Collection-Level Metadata: A TELDAP Case Study"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1022"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Hsueh-hua Chen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Chiung-min Tsai"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Ya-Chen Ho"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# CREATE
# LAST	Len	"Establishing a Multi-Thesauri-Scenario based on SKOS and Cross-Concordances"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1476	en:"Establishing a Multi-Thesauri-Scenario based on SKOS and Cross-Concordances"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/1031"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P1433	Q68241000	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
#
# LAST	P2093	"Philipp Mayr"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"Benjamin Zapilko"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
# LAST	P2093	"York Sure"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/35"
