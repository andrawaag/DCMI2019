# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2009

# %% [markdown]
# ## Create conference Item

# %%
year = "2009"
location = "Seoul"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2009"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2009: Seoul"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2009"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2009"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68268757"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/33" ## Needs to be changed
location = "2009 in Seoul, Korea, 12-16 October 2009" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2009 International Conference on Dublin Core and Metadata Applications, DC-2009 in 2009 in Seoul, Korea, 12-16 October 2009"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Proceedings of the 2009 International Conference on Dublin Core and Metadata Applications, DC-2009 in 2009 in Seoul, Korea, 12-16 October 2009"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P4745	Q68268757	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"

# %%
proceedingsQID = "Q68269133"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Modeling Classification Systems in SKOS: Some Challenges and Best-Practice Recommendations"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Modeling Classification Systems in SKOS: Some Challenges and Best-Practice Recommendations"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/974"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Michael Panzer"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Marcia Lei Zeng"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Using Metadata for Query Refinement and Recommendation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Using Metadata for Query Refinement and Recommendation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/955"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Jian Qin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Xiaozhong Liu"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Xia Lin"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Miao Chen"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"A Unified Approach for Representing Metametadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"A Unified Approach for Representing Metametadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/973"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Kai Eckert"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Magnus Pfeffer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Heiner Stuckenschmidt"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Is Tagging Effective? – Overlapping Ratios with Other Metadata Fields"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Is Tagging Effective? – Overlapping Ratios with Other Metadata Fields"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/975"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Wooseob Jeong"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Knowledge Management and Dublin Core"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Knowledge Management and Dublin Core"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/953"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Jon Mason"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Multilayered Paper Prototyping for User Concept  Modeling: Supporting the Development of Application Profiles"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Multilayered Paper Prototyping for User Concept  Modeling: Supporting the Development of Application Profiles"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/990"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Emma Tonkin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Metadata Framework for Manga: A Multi-paradigm Metadata Description Framework for Digital Comics"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Metadata Framework for Manga: A Multi-paradigm Metadata Description Framework for Digital Comics"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/979"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Ayako Morozumi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Satomi Nomura"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Mitsuharu Nagamori"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Archiving and Management of Digital Images Based on an Embedded Metadata Framework"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Archiving and Management of Digital Images Based on an Embedded Metadata Framework"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/951"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Cjien-cheng Liu"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Chao-chen Chen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Building a Strong Foundation with Dublin Core"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Building a Strong Foundation with Dublin Core"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/962"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Linda F. Powell"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Television Heritage and the Semantic Web:  Video Active and EUscreen"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Television Heritage and the Semantic Web:  Video Active and EUscreen"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/969"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Johan Oomen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Anna Christaki"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Vassilis Tzouvaras"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"A Semantic MediaWiki-Empowered Terminology Registry"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"A Semantic MediaWiki-Empowered Terminology Registry"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/949"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Qing Zou"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Wei Fan"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Research on Linked Data and Co-reference Resolution"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Research on Linked Data and Co-reference Resolution"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/958"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Hugh Glaser"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Ian Millard"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Won-Kyung Sung"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Seungwoo Lee"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Pyung Kim"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Beom-Jong You"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Towards Linked Education Data: Metadata Extraction Projects for Education Network Australia (edna)"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Towards Linked Education Data: Metadata Extraction Projects for Education Network Australia (edna)"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/978"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Sarah Lindsay Hayman"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Nick Lothian"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Report of a World-wide Survey on Metadata Decisions for Digital Libraries"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Report of a World-wide Survey on Metadata Decisions for Digital Libraries"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/956"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Marcia Lei Zeng"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Jaesun Lee"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Allene F. Hayes"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Structuring Serials Bibliographic Relationships through ID Linking"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Structuring Serials Bibliographic Relationships through ID Linking"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/959"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Haiyan Bai"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Yung-Lung Cho"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Effectiveness of Query Expansion using Flickr Related Tags"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Effectiveness of Query Expansion using Flickr Related Tags"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/961"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"JungWon Yoon"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Ontology-based meta-framework for metadata interoperability"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Ontology-based meta-framework for metadata interoperability"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/963"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Seungmin Lee"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"CiNii: Bringing Linked Data to Japan's Largest Scholarly Search Engine"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"CiNii: Bringing Linked Data to Japan's Largest Scholarly Search Engine"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/966"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Ikki Ohmukai"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Hideaki Takeda"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Federated Searching System for Humanities Databases Using Automatic Metadata Mapping"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Federated Searching System for Humanities Databases Using Automatic Metadata Mapping"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/967"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Fuminori Kimura"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Takushi Toba"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Taro Tezuka"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Akira Maeda"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"DigitalNZ ā-tihi o Aotearoa: Connecting the Digital Content of New Zealand: Advice, Open Standards and Interoperability."
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"DigitalNZ ā-tihi o Aotearoa: Connecting the Digital Content of New Zealand: Advice, Open Standards and Interoperability."	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/982"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Karen Rollitt"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# CREATE
# LAST	Len	"Designing AGRIS 2010 - Information Linking and Agricultural Research"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1476	en:"Designing AGRIS 2010 - Information Linking and Agricultural Research"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/986"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P1433	Q68269133	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
#
# LAST	P2093	"Dan Brickley"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Johannes Keizer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
# LAST	P2093	"Stefano Anibaldi"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/33"
