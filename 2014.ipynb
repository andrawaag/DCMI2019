# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2014

# %% [markdown]
# ## Create conference Item

# %%
print("CREATE")
print("LAST\tLen\t\"DC-2014\"")     ## Needs to be changed
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-2014: Austin\"") ## Needs to be changed
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-2014\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Needs to be changed
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/2015\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Need to be changed
# Out:
# CREATE
# LAST	Len	"DC-2014"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2014: Austin"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2014"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2015"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68237279"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view//166" ## Needs to be changed
year = "2014" ## Needs to be changed
location = "Austin, Texas, 8-11 October 2014" ## Needs to be changed
print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2014 International Conference on Dublin Core and Metadata Applications, DC-2014 in Austin, Texas, 8-11 October 2014"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Proceedings of the 2014 International Conference on Dublin Core and Metadata Applications, DC-2014 in Austin, Texas, 8-11 October 2014"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P4745	Q68237279	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"

# %%
proceedingsQID = "Q68238124"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
for article in table:
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Introductions and Committees"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Introductions and Committees"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3698"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Linked Data Mapping Cultures: An Evaluation of Metadata Usage and Distribution in a Linked Data Environment"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Linked Data Mapping Cultures: An Evaluation of Metadata Usage and Distribution in a Linked Data Environment"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3699"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Konstantin Baierer"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Evelyn Dröge"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Vivien Petras"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Violeta Trkulja"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"The Digital Public Library of America Ingestion Ecosystem: Lessons Learned After One Year of Large-Scale Collaborative Metadata Aggregation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"The Digital Public Library of America Ingestion Ecosystem: Lessons Learned After One Year of Large-Scale Collaborative Metadata Aggregation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3700"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Mark A. Matienzo"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Amy Rudersdorf"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"How Descriptive Metadata Changes in the UNT Libraries' Collections: A Case Study"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"How Descriptive Metadata Changes in the UNT Libraries' Collections: A Case Study"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3701"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Hannah Tarver"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Oksana Zavalina"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Mark Phillips"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Daniel Alemneh"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Shadi Shakeri"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Metadata Integration for an Archaeology Collection Architecture"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Metadata Integration for an Archaeology Collection Architecture"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3702"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Sivakumar Kulasekaran"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Jessica Trelogan"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Maria Esteva"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Michael Johnson"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Dublin Core Metadata for Research Data - Lessons Learned in a Real-World Scenario with datorium"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Dublin Core Metadata for Research Data - Lessons Learned in a Real-World Scenario with datorium"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3703"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Andias Wira Alam"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"The ARK Identifier Scheme: Lessons Learnt at the BnF and Questions Yet Unanswered"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"The ARK Identifier Scheme: Lessons Learnt at the BnF and Questions Yet Unanswered"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3704"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Sébastien Peyrard"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"John A. Kunze"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Jean-Philippe Tramoni"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Requirements on RDF Constraint Formulation and Validation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Requirements on RDF Constraint Formulation and Validation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3705"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Thomas Bosch"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Kai Eckert"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Extracting Description Set Profiles from RDF Datasets using Metadata Instances and SPARQL Queries"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Extracting Description Set Profiles from RDF Datasets using Metadata Instances and SPARQL Queries"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3706"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Tsunagu Honma"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Kei Tanaka"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Mitsuharu Nagamori"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"The 1:1 Principle in the Age of Linked Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"The 1:1 Principle in the Age of Linked Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3707"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Richard J. Urban"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Towards Description Set Profiles for RDF using SPARQL as Intermediate Language"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Towards Description Set Profiles for RDF using SPARQL as Intermediate Language"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3708"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Thomas Bosch"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Kai Eckert"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Provenance Description of Metadata using PROV with PREMIS for Long-term Use of Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Provenance Description of Metadata using PROV with PREMIS for Long-term Use of Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3709"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Chunqiu Li"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Interlinking Cross Language Metadata Using Heterogeneous Graphs and Wikipedia"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Interlinking Cross Language Metadata Using Heterogeneous Graphs and Wikipedia"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3710"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Xiaozhong Liu"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Miao Chen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Jian Qin"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Applying a linked data compliant model: The usage of the Europeana Data Model by the Deutsche Digitale Bibliothek"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Applying a linked data compliant model: The usage of the Europeana Data Model by the Deutsche Digitale Bibliothek"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3711"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Stefanie Rühle"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Francesca Schulze"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Michael Büchner"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Designing a Multi-level Metadata Standard based on Dublin Core for Museum Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Designing a Multi-level Metadata Standard based on Dublin Core for Museum Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3712"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Jing Wan"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Yubin Zhou"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Gang Chen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Junkai Yi"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	""Lo-Fi to Hi-Fi": A New Metadata Approach in the Third World with the eGranary Digital Library"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:""Lo-Fi to Hi-Fi": A New Metadata Approach in the Third World with the eGranary Digital Library"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3713"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Deborah Maron"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Cliff Missen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Jane Greenberg"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Metadata for Research Data: Current Practices and Trends"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Metadata for Research Data: Current Practices and Trends"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3714"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Sharon Farnel"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Ali Shiri"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Describing Theses and Dissertations Using Schema.org"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Describing Theses and Dissertations Using Schema.org"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3715"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Jeff Keith Mixter"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Patrick OBrien"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Kenning Arlitsch"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Automated Enhancement of Controlled Vocabularies: Upgrading Legacy Metadata in CONTENTdm"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Automated Enhancement of Controlled Vocabularies: Upgrading Legacy Metadata in CONTENTdm"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3716"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Andrew Weidner"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Annie Wu"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Santi Thompson"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Retaining Metadata in Remixed Cultural Heritage Objects"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Retaining Metadata in Remixed Cultural Heritage Objects"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3717"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Jamie Viva Wittenberg"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Embedded Metadata -- A Tool for Digital Excavation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Embedded Metadata -- A Tool for Digital Excavation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3718"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Ana Cox"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Dublin Core to Ensure Interoperability between Models Generated by Tools of Species Distribution Modeling"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Dublin Core to Ensure Interoperability between Models Generated by Tools of Species Distribution Modeling"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3719"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Cleverton Ferreira Borba"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Pedro Luiz P. Correa"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Building Bridges to the Future of a Distributed Network: From DiRT Categories to TaDiRAH, a Methods Taxonomy for Digital Humanities"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Building Bridges to the Future of a Distributed Network: From DiRT Categories to TaDiRAH, a Methods Taxonomy for Digital Humanities"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3720"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Jody Perkins"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Quinn Dombrowski"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Luise Borek"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Christof Schöch"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Metadata Workflows Across Research Domains: Challenges and Opportunities for Supporting the DFC Cyberinfrastructure"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Metadata Workflows Across Research Domains: Challenges and Opportunities for Supporting the DFC Cyberinfrastructure"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3721"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Adrian T. Ogletree"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"A Cooperative Project by Libraries and Museums of China: Metadata Standards for the Digital Preservation of Cultural Heritage"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"A Cooperative Project by Libraries and Museums of China: Metadata Standards for the Digital Preservation of Cultural Heritage"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3722"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Ying Feng"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Long Xiao"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# CREATE
# LAST	Len	"Undressing Fashion Metadata: Ryerson University Fashion Research Collection"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1476	en:"Undressing Fashion Metadata: Ryerson University Fashion Research Collection"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3723"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P1433	Q68238124	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
#
# LAST	P2093	"Naomi Eichenlaub"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Marina Morgan"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
# LAST	P2093	"Ingrid Masak-Mida"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view//166"
