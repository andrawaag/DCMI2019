# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2006

# %% [markdown]
# ## Create conference Item

# %%
year = "2006"
location = "Manzanillo"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2006"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2006: Manzanillo"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2006"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2006"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68278578"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/29" ## Needs to be changed
location = " Manzanillo, Colima, Mexico, 3-6 October 2006" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2006 International Conference on Dublin Core and Metadata Applications, DC-2006 in  Manzanillo, Colima, Mexico, 3-6 October 2006"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Proceedings of the 2006 International Conference on Dublin Core and Metadata Applications, DC-2006 in  Manzanillo, Colima, Mexico, 3-6 October 2006"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P4745	Q68278578	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"

# %%
proceedingsQID = "Q68278790"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Towards an interoperability framework for metadata standards"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Towards an interoperability framework for metadata standards"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/835"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Mikael Nilsson"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Pete Johnston"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Ambjörn Naeve"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Andy Powell"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"DC-Text -- A simple text-based format for DC metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"DC-Text -- A simple text-based format for DC metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/836"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Pete Johnston"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Andy Powell"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Toward a collection-based metadata maintenance model"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Toward a collection-based metadata maintenance model"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/837"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Martin Kurth"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Jim LeBlanc"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Using the DC Abstract Model to support application profile developers"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Using the DC Abstract Model to support application profile developers"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/838"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Sarah Pulis"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Liddy Nevile"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"SKOS: Requirements for standardization"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"SKOS: Requirements for standardization"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/839"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Alistair Miles"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"A Metadata registry from vocabularies up: The NSDL registry project"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"A Metadata registry from vocabularies up: The NSDL registry project"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/840"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Diane I. Hillmann"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Stuart A. Sutton"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Jon Phipps"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Ryan Laundry"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"From AGROVOC to the Agricultural Ontology Service / Concept Server: An OWL model for creating ontologies in the agricultural domain"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"From AGROVOC to the Agricultural Ontology Service / Concept Server: An OWL model for creating ontologies in the agricultural domain"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/841"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"A. C. Liang"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Boris Lauser"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Margherita Sini"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Johannes Keizer"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Stephen Katz"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Encoding Library of Congress Subject Headings in SKOS: Authority control for the Semantic Web"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Encoding Library of Congress Subject Headings in SKOS: Authority control for the Semantic Web"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/842"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Corey A. Harper"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Implementing an institutional repository for digital archive communities: Experiences from National Taiwan University"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Implementing an institutional repository for digital archive communities: Experiences from National Taiwan University"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/843"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Chiung-min Tsai"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Jieh Hsiang"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Hsueh-hua Chen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Dublin Core as a tool for interoperability: Common presentation of data from archives, libraries and museums"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Dublin Core as a tool for interoperability: Common presentation of data from archives, libraries and museums"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/844"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Leif Andresen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Eureka! Dublin Core based metadata supports the Archimedes Palimpsest Manuscript Imaging Program"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Eureka! Dublin Core based metadata supports the Archimedes Palimpsest Manuscript Imaging Program"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/845"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Michael B. Toth"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"William A. Christens-Barry"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Roger L. Easton"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Metadata towards an e-research cyberinfrastructure: The case of French PhD theses"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Metadata towards an e-research cyberinfrastructure: The case of French PhD theses"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/846"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Jacques Ducloy"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Jean-Paul Ducasse"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Muriel Foulonneau"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Luc Grivel"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Diane Le Hénaff"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Yann Nicolas"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Vocabularies for describing pedagogical approach in e-Learning: A scoping study"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Vocabularies for describing pedagogical approach in e-Learning: A scoping study"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/847"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Sarah Currier"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Sheila MacNeill"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Lisa Corley"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Lorna Campbell"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Helen Beetham"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Virtual reality learning objects of molecular structures"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Virtual reality learning objects of molecular structures"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/848"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Miguel A. Garcia-Ruiz"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Arthur Edwards"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Jorge R. Gutierrez-Pulido"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Ricardo Acosta-Diaz"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Memex Metadata (M2) for reflective learning"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Memex Metadata (M2) for reflective learning"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/849"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Jane Greenberg"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Abe Crystal"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Anuj Sharma"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Eva M. Méndez"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"John Oberlin"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Michael Shoffner"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Using FRBR for the selection and adaptation of accessible resources"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Using FRBR for the selection and adaptation of accessible resources"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/850"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Ayako Morozumi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Mitsuharu Nagamori"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Liddy Nevile"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Semantic mediacasting and collaborative feed sharing"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Semantic mediacasting and collaborative feed sharing"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/851"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Narendra Kumar Shukla"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Anand Agrawal"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Development of a wiki-based, expert community-driven nanosystem vocabulary"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Development of a wiki-based, expert community-driven nanosystem vocabulary"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/852"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Laura M. Bartolo"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Cathy S. Lowe"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Sharon C. Glotzer"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Christopher Iacovella"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Identity matters: Constructing social identities through ontology-based metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Identity matters: Constructing social identities through ontology-based metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/853"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Maria Cristina Pattuelli"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Lisa R. Norberg"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"DCMI abstract model analysis: Resource model"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"DCMI abstract model analysis: Resource model"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/854"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Vicente Palacios"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Jorge Morato"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Juan B. Llorens"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Jose A. Moreiro"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Developing cultural heritage preservation databases based on Dublin Core data elements"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Developing cultural heritage preservation databases based on Dublin Core data elements"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/855"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Fenella G. France"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Michael B. Toth"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Redalyc OAI-PMH: The Open Archives Initiative Protocol for Metadata Harvesting (Protocol Version 2.0)"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Redalyc OAI-PMH: The Open Archives Initiative Protocol for Metadata Harvesting (Protocol Version 2.0)"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/856"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Eduardo Aguado López"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Rosario Rogel Salazar"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Arianna Becerril García"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Honorio García Flores"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Development of a controlled vocabulary for learning objects' functional description in an educational repository"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Development of a controlled vocabulary for learning objects' functional description in an educational repository"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/857"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Miguel Ángel Marzal"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Mª Jesús Colmenero Ruiz"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Aurora Cuevas Cerveró"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Customising location of knowledge"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Customising location of knowledge"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/858"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Ann Apps"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Ross MacIntyre"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Linking legal sources in a shared web environment"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Linking legal sources in a shared web environment"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/859"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Enrico Francesconi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Ginevra Peruginelli"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"The Semantic Network Service -- Supporting Heterogeneous Environmental Information Systems"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"The Semantic Network Service -- Supporting Heterogeneous Environmental Information Systems"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/860"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Matthias Menger"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Maria Rüther"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# CREATE
# LAST	Len	"Signed metadata: Method and application"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1476	en:"Signed metadata: Method and application"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/861"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P1433	Q68278790	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
#
# LAST	P2093	"Emma Tonkin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
# LAST	P2093	"Julie Allinson"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/29"
