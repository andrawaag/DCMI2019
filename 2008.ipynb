# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2008

# %% [markdown]
# ## Create conference Item

# %%
year = "2008"
location = "Berlin"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2008"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2008: Berlin"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2008"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2008"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68277652"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/32" ## Needs to be changed
location = " Berlin, 22-26 September 2008" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2008 International Conference on Dublin Core and Metadata Applications, DC-2008 in  Berlin, 22-26 September 2008"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Proceedings of the 2008 International Conference on Dublin Core and Metadata Applications, DC-2008 in  Berlin, 22-26 September 2008"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P4745	Q68277652	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"

# %%
proceedingsQID = "Q68277889"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Encoding Application Profiles in a Computational Model of the                 Crosswalk"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Encoding Application Profiles in a Computational Model of the                 Crosswalk"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/914"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Carol Jean Godby"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Devon Smith"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Eric Childress"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Relating Folksonomies with Dublin Core"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Relating Folksonomies with Dublin Core"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/915"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Maria Elisabete Catarino"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Ana Alice Baptista"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"LCSH, SKOS and Linked Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"LCSH, SKOS and Linked Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/916"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Ed Summers"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Antoine Isaac"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Clay Redding"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Dan Krech"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Theme Creation for Digital Collections"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Theme Creation for Digital Collections"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/917"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Xia Lin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Jiexun Li"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Xiaohua Zhou"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Comparing Human and Automatic Thesaurus Mapping Approaches in the                Agricultural Domain"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Comparing Human and Automatic Thesaurus Mapping Approaches in the                Agricultural Domain"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/918"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Boris Lauser"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Gudrun Johannsen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Caterina Caracciolo"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Willem Robert van Hage"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Johannes Keizer"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Philipp Mayr"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Automatic Metadata Extraction From Museum Specimen Labels"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Automatic Metadata Extraction From Museum Specimen Labels"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/919"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"P. Bryan Heidorn"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Qin Wei"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Achievement Standards Network (ASN): An Application Profile for                Mapping K-12 Educational Resources to Achievement Standards"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Achievement Standards Network (ASN): An Application Profile for                Mapping K-12 Educational Resources to Achievement Standards"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/920"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Stuart Allen Sutton"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Diny Golder"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Collection/Item Metadata Relationships"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Collection/Item Metadata Relationships"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/921"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Allen H. Renear"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Karen M. Wickett"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Richard J. Urban"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"David Dubin"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Sarah L. Shreeves"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Answering the Call for more Accountability: Applying Data                Profiling to Museum Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Answering the Call for more Accountability: Applying Data                Profiling to Museum Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/922"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Seth van Hooland"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Yves Bontemps"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Seth Kaufman"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"A Conceptual Framework for Metadata Quality Assessment"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"A Conceptual Framework for Metadata Quality Assessment"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/923"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Thomas Margaritopoulos"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Merkourios Margaritopoulos"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Ioannis Mavridis"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Athanasios Manitsaris"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Semantic Relation Extraction from Socially-Generated Tags: A                Methodology for Metadata Generation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Semantic Relation Extraction from Socially-Generated Tags: A                Methodology for Metadata Generation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/924"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Miao Chen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Xiaozhong Liu"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Jian Qin"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"The State of the Art in Tag Ontologies: A Semantic Model for                Tagging and Folksonomies"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"The State of the Art in Tag Ontologies: A Semantic Model for                Tagging and Folksonomies"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/925"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Hak Lae Kim"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Simon Scerri"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"John G. Breslin"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Stefan Decker"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Hong Gee Kim"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"DCMF: DC & Microformats, a good marriage"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"DCMF: DC & Microformats, a good marriage"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/926"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Eva M. Méndez"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Leandro M Lopez"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Arnau Siches"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Alejandro G. Bravo"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Making a Library Catalogue Part of the Semantic Web"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Making a Library Catalogue Part of the Semantic Web"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/927"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Martin Malmsten"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"The Dryad Data Repository: A Singapore Framework Metadata                 Architecture in a DSpace Environment"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"The Dryad Data Repository: A Singapore Framework Metadata                 Architecture in a DSpace Environment"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/928"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Hollie C. White"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Sarah Carrier"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Abbey Thompson"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Jane Greenberg"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Ryan Scherle"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Applying DCMI Elements to Digital Images and Text in the                Archimedes Palimpsest Program"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Applying DCMI Elements to Digital Images and Text in the                Archimedes Palimpsest Program"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/929"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Michael Toth"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Doug Emery"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Assessing Descriptive Substance in Free-Text Collection-Level                Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Assessing Descriptive Substance in Free-Text Collection-Level                Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/930"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Oksana Zavalina"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Carole Palmer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Amy S. Jackson"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Myung-Ja Han"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Building a Terminology Network for Search: The KoMoHe Project"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Building a Terminology Network for Search: The KoMoHe Project"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/931"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Philipp Mayr"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Vivien Petras"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Cool URIs for the DDC: Towards Web-scale Accessibility of a Large                Classification System"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Cool URIs for the DDC: Towards Web-scale Accessibility of a Large                Classification System"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/932"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Michael Panzer"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"The Specification of the Language of the Field and                Interoperability: Cross-language Access to Catalogues and Online Libraries (CACAO)"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"The Specification of the Language of the Field and                Interoperability: Cross-language Access to Catalogues and Online Libraries (CACAO)"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/933"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Barbara Levergood"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Stefan Farrenkopf"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Elisabeth Frasnelli"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Implementation of Rich Metadata Formats and Semantic Tools using                DSpace"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Implementation of Rich Metadata Formats and Semantic Tools using                DSpace"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/934"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Imma Subirats"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"ARD Prasad"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Johannes Keizer"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Andrew Bagdanov"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"SKOS for an Integrated Vocabulary Structure"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"SKOS for an Integrated Vocabulary Structure"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/935"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Marcia Lei Zeng"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Wei Fan"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Xia Lin"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Exploring Evolutionary Biologists’ Use and Perceptions of Semantic                Metadata for Data Curation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Exploring Evolutionary Biologists’ Use and Perceptions of Semantic                Metadata for Data Curation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/936"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Hollie C White"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"LCSH is to Thesaurus as Doorbell is to Mammal: Visualizing                Structural Problems in the Library of Congress Subject Headings"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"LCSH is to Thesaurus as Doorbell is to Mammal: Visualizing                Structural Problems in the Library of Congress Subject Headings"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/937"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Simon E Spero"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Metadata in an Ecosystem of Presentation Dissemination"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Metadata in an Ecosystem of Presentation Dissemination"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/938"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"R John Robertson"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Phil Barker"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Mahendra Mahey"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"A Comparison of Social Tagging Designs and User Participation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"A Comparison of Social Tagging Designs and User Participation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/939"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Caitlin M Bentley"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Patrick Labelle"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"The Data Documentation Initiative (DDI)"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"The Data Documentation Initiative (DDI)"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/940"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Joachim Wackerow"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"junii2 and AIRway: An Application Profile for Scholarly Works and                Its Application for Link Resolvers"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"junii2 and AIRway: An Application Profile for Scholarly Works and                Its Application for Link Resolvers"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/941"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Kunie Horikoshi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Shigeki Sugita"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Yuji Nonaka"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Satsuki Kamiya"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Izumi Sugita"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Haruo Asoshina"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Open Identification and Linking of the Four Ws"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Open Identification and Linking of the Four Ws"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/942"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Ryan Shaw"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Michael Buckland"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Web 2.0 Semantic Systems: Collaborative Learning in Science"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Web 2.0 Semantic Systems: Collaborative Learning in Science"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/943"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Michael Shoffner"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Jane Greenberg"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"Jacob Kramer-Duffield"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P2093	"David Woodbury"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Doing the LibraryThing in an Academic Library Catalog"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Doing the LibraryThing in an Academic Library Catalog"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/944"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Christine DeZelar-Tiedman"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# CREATE
# LAST	Len	"Applying DC to Institutional Data Repositories"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1476	en:"Applying DC to Institutional Data Repositories"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/945"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
# LAST	P1433	Q68277889	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
#
# LAST	P2093	"Robin C Rice"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/32"
