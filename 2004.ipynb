# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2004

# %% [markdown]
# ## Create conference Item

# %%
year = "2004"
location = "Shanghai"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2004"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2004: Shanghai"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2004"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2004"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68279770"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/27" ## Needs to be changed
location = " Shanghai, China, 11-14 October 2004" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2004 International Conference on Dublin Core and Metadata Applications, DC-2004 in  Shanghai, China, 11-14 October 2004"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Proceedings of the 2004 International Conference on Dublin Core and Metadata Applications, DC-2004 in  Shanghai, China, 11-14 October 2004"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P4745	Q68279770	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"

# %%
proceedingsQID = "Q68279868"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"A Metadata schema framework for functional extension of metadata schema registry"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"A Metadata schema framework for functional extension of metadata schema registry"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/764"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Mitsuharu Nagamori"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Maintaining a vocabulary: Practices, policies, and models around Dublin Core"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Maintaining a vocabulary: Practices, policies, and models around Dublin Core"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/765"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Thomas Baker"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Towards a Language for Metadata Schemas for Interoperability"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Towards a Language for Metadata Schemas for Interoperability"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/766"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Vilas Wuwongse"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Making Metadata go away: "Hiding everything but the benefits""
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Making Metadata go away: "Hiding everything but the benefits""	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/767"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Erik Duval"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Wayne Hodgins"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Opening the legal literature Portal to multilingual access"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Opening the legal literature Portal to multilingual access"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/768"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Enrico Francesconi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Ginevra Peruginelli"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Managing digital objects and their metadata: challenges and responses"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Managing digital objects and their metadata: challenges and responses"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/769"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Adrienne Kebbell"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Douglas Campbell"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Improving Metadata Quality: Augmentation and Recombination"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Improving Metadata Quality: Augmentation and Recombination"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/770"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Diane I. Hillmann"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Naomi Dushay"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Jon Phipps"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"A Registry of Collections and their Services: from Metadata to Implementation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"A Registry of Collections and their Services: from Metadata to Implementation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/771"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Ann Apps"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Describing and analyzing the recordkeeping capabilities of metadata sets"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Describing and analyzing the recordkeeping capabilities of metadata sets"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/772"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Joanne Evans"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Lori Lindberg"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Metadata Harvesting Framework in P2P-Based Digital Libraries"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Metadata Harvesting Framework in P2P-Based Digital Libraries"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/773"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Hao Ding"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Hao Ding"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Metadata Exchange without pain: the AGRIS AP to harvest and exchange quality metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Metadata Exchange without pain: the AGRIS AP to harvest and exchange quality metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/774"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Irene Onyancha"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"James Weinheimer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Gauri Salokhe"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Stephen Katz"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Johannes Keizer"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Metadata and Controlled Vocabularies in the Government of Canada: A Situational Analysis"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Metadata and Controlled Vocabularies in the Government of Canada: A Situational Analysis"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/775"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Gregory Renaud"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"A Study on Audiovisual Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"A Study on Audiovisual Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/776"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Duan Minglian"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Yao Xingxing"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Zhang Jiuzhen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"XMetaDiss--Metadata for ETDs in Germany"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"XMetaDiss--Metadata for ETDs in Germany"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/777"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"C. Frodl"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"N. Korb"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"T. Wollschlaeger"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Research on Interoperability of Metadata in Classification Schemes--construction of automatic mapping system between CLC and DDC"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Research on Interoperability of Metadata in Classification Schemes--construction of automatic mapping system between CLC and DDC"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/778"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Jianbo Dai"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Hanqing Hou"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Ling Cao"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"METS-Based Cataloging Toolkit for Digital Library Management System"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"METS-Based Cataloging Toolkit for Digital Library Management System"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/779"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Li Dong"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Bei Zhang"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Chunxiao Xing"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Lizhu Zhou"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"The Case for a Person/Agent Dublin Core Metadata Element Set"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"The Case for a Person/Agent Dublin Core Metadata Element Set"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/780"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Liddy Nevile"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Sophie Lissonnet"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"A methodology for metadata modelling--depth for a flat world"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"A methodology for metadata modelling--depth for a flat world"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/781"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Andreas Aschenbrenner"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"A Metadata Model Based on the Concept of Structured Digital Object(SDO) and Its Application in Digital Libraries--From Concept to Prototype System"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"A Metadata Model Based on the Concept of Structured Digital Object(SDO) and Its Application in Digital Libraries--From Concept to Prototype System"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/782"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Ying Li"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Hidehiro Ishizuka"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"The Preservation Metadata Schema of the Military Academy Digital Library Application Software System of China"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"The Preservation Metadata Schema of the Military Academy Digital Library Application Software System of China"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/783"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Wang Songlin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Liu Yu"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Leveraging Metadata Inductively and Subjectively"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Leveraging Metadata Inductively and Subjectively"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/784"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Stephen Davies"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Roger King"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"The Design of Metadata Schemas for Chinese Cultural Celebrities' Manuscript Library"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"The Design of Metadata Schemas for Chinese Cultural Celebrities' Manuscript Library"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/785"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Wei Liu"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Cuijuan Xia"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Liang Zhao"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Xiangying Lou"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Chunjing Zhang"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Metadata element sets in the CISMeF Quality-Controlled Health Gateway"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Metadata element sets in the CISMeF Quality-Controlled Health Gateway"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/786"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Benoit Thirion"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Magaly Douyère"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Lina F. Soualmia"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Badisse Dahamna"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Jean-Philippe Leroy"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Stéfan J. Darmoni"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Providing Metadata to Historical Material on Viewer Application iPalletnexus"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Providing Metadata to Historical Material on Viewer Application iPalletnexus"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/787"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Norio Togiya"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Mitsuhiro Tsuda"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Akira  Baba"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"A Metadata Description Scheme and Corresponding Visual Methods of Teaching Resources Libraries"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"A Metadata Description Scheme and Corresponding Visual Methods of Teaching Resources Libraries"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/788"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Ning Zhou"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Wei Liu"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Chuanzhi Yang"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Jiaxin Wu"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Chi Zhang"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Metadata Management System (MMS)"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Metadata Management System (MMS)"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/789"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Norhaizan Mat Talha"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"FINDEX--Meta Information System for Substances"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"FINDEX--Meta Information System for Substances"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/790"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Matthias Menger"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Petra Jahnke"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"CANOE: A Course Assembly and Normalization Tool for E-learning"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"CANOE: A Course Assembly and Normalization Tool for E-learning"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/791"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Han Xu"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Honghan Wu"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Yuzhong Qu"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Open Source Software to Manage Digital Collections in a Decentralized Environment"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Open Source Software to Manage Digital Collections in a Decentralized Environment"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/792"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Scott A. Gunn"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Metadata Generation and Accessibility Auditing"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Metadata Generation and Accessibility Auditing"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/793"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"Liddy Nevile"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# CREATE
# LAST	Len	"Architecting a Cross-Disciplinary Thesaurus for the Semantic Web"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1476	en:"Architecting a Cross-Disciplinary Thesaurus for the Semantic Web"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/794"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P1433	Q68279868	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
#
# LAST	P2093	"W. Davenport Robertson"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
# LAST	P2093	"Jane Greenberg"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/27"
