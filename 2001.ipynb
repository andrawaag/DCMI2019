# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2003

# %% [markdown]
# ## Create conference Item

# %%
year = "2003"
location = "Seattle"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2003"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2003: Seattle"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2003"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2003"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68280271"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/26" ## Needs to be changed
location = " Seattle, 28 September - 2 October 2003" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2003 International Conference on Dublin Core and Metadata Applications, DC-2003 in  Seattle, 28 September - 2 October 2003"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Proceedings of the 2003 International Conference on Dublin Core and Metadata Applications, DC-2003 in  Seattle, 28 September - 2 October 2003"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P4745	Q68280271	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"

# %%
proceedingsQID = "Q68280420"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Integrating Metadata Schema Registries with Digital Preservation Systems to Support Interoperability: a Proposal"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Integrating Metadata Schema Registries with Digital Preservation Systems to Support Interoperability: a Proposal"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/728"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Michael Day"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Metadata schema registries in the partially Semantic Web: the CORES experience"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Metadata schema registries in the partially Semantic Web: the CORES experience"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/729"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Rachel Heery"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Pete Johnston"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Csaba Fülöp"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"András Micsik"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Two Paths to Interoperable Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Two Paths to Interoperable Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/730"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Carol Jean Godby"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Devon Smith"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Eric Rogers Childress"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Search and Delivery of Standardized Learning Resources Based on SOAP Messaging and Native XML Databases"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Search and Delivery of Standardized Learning Resources Based on SOAP Messaging and Native XML Databases"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/731"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Xin Xiang"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Ling Guo"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Yuanchun Shi"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Building Quality Assurance into Metadata Creation: An Analysis based on the Learning Objects and e-Prints Communities of Practice"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Building Quality Assurance into Metadata Creation: An Analysis based on the Learning Objects and e-Prints Communities of Practice"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/732"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Jane Barton"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Sarah Currier"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Jessie M. N. Hey"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Iterative Design of Metadata Creation Tools for Resource Authors"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Iterative Design of Metadata Creation Tools for Resource Authors"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/733"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Jane Greenberg"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Abe Crystal"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"W. Davenport Robertson"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Ellen Leadem"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"A Subject gateway in Multiple Languages: A Prototype Development and Lessons Learned"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"A Subject gateway in Multiple Languages: A Prototype Development and Lessons Learned"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/734"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Wonsook Lee"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Mitsuharu Nagamori"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Tetsuo Sakaguchi"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Koichi Tabata"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Distributing and Synchronizing Heterogeneous Metadata for the Management of Geospatial Information Repositories"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Distributing and Synchronizing Heterogeneous Metadata for the Management of Geospatial Information Repositories"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/735"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Elaine L. Westbrooks"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Statistical Metadata Needs during Integration Tasks"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Statistical Metadata Needs during Integration Tasks"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/736"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Sheila Denn"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Stephanie W. Haas"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Carol A. Hert"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Functional Requirements of Metadata System: From User Needs Perspective"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Functional Requirements of Metadata System: From User Needs Perspective"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/737"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Ya-ning Chen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Shu-jiun Chen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Hon-chung Sum"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Simon C. Lin"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Access to Italian legal literature: Integration between Structured Repositories and Web Documents"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Access to Italian legal literature: Integration between Structured Repositories and Web Documents"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/738"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Enrico Francesconi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"G. Peruginell"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"The Use of Metadata for the Identification and Retrieval of Resources for K–12 Education"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"The Use of Metadata for the Identification and Retrieval of Resources for K–12 Education"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/739"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"John S. Kendall"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Metadata in the Collaboratory for Multi-Scale Chemical Science"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Metadata in the Collaboratory for Multi-Scale Chemical Science"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/740"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Carmen Pancerella"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"John Hewson"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Wendy Koegler"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"David Leahy"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Michael Lee"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Larry Rahn"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Christine Yang"	P1545	"7"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"James D. Myers"	P1545	"8"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Brett Didier"	P1545	"9"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Renata McCoy"	P1545	"10"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Karen Schuchardt"	P1545	"11"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Eric Stephan"	P1545	"12"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Theresa Windus"	P1545	"13"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Kaizar Amin"	P1545	"14"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Sandra Bittner"	P1545	"15"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Carina Lansing"	P1545	"16"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Michael Minkoff"	P1545	"17"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Sandeep Nijsure"	P1545	"18"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Gregor von Laszewski"	P1545	"19"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Reinhardt Pinzon"	P1545	"20"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Branko Ruscic"	P1545	"21"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Al Wagner"	P1545	"22"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Baoshan Wang"	P1545	"23"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"William Pitz"	P1545	"24"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Yen-Ling Ho"	P1545	"25"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"David Montoya"	P1545	"26"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Lili Xu"	P1545	"27"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Thomas C. Allison"	P1545	"28"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"William H. Green"	P1545	"29"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Jr."	P1545	"30"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Michael Frenklach"	P1545	"31"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Metadata with a MISSION: Using Metadata to Query Distributed Statistical Meta-information Syste"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Metadata with a MISSION: Using Metadata to Query Distributed Statistical Meta-information Syste"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/741"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Sally McClean"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Brian Scotney"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Hans Rutjes"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Using the OpenURL Framework to Locate Bibliographic Resources"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Using the OpenURL Framework to Locate Bibliographic Resources"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/742"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Ann Apps"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Ross MacIntyre"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Structured Metadata for Direct Resource Location: A Case Study"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Structured Metadata for Direct Resource Location: A Case Study"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/743"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Gauri Salokhe"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"James Weinheimer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Maria Grazia Bovo"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Moira Agrimi"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Johannes Keizer"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Stephen Katz"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Analyzing Metadata for Effective Use and Re-Use"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Analyzing Metadata for Effective Use and Re-Use"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/744"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Naomi Dushay"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Diane I. Hillmann"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Assessing Metadata Utilization:  An Analysis of MARC Content Designation Use"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Assessing Metadata Utilization:  An Analysis of MARC Content Designation Use"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/745"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"William E. Moen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Penelope Benardino"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Towards Identity Conditions for Digital Documents"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Towards Identity Conditions for Digital Documents"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/746"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Allen Renear"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"David Dubin"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"AMS--Metadata for Cultural Exhibitions using Virtual Reality"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"AMS--Metadata for Cultural Exhibitions using Virtual Reality"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/747"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Nicholaos Mourkoussis"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Martin White"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Manjula Patel"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Jacek Chmielewski"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Krzysztof Walczak"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Imagining the Northwest : A Digital Library Partnership in Oregon"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Imagining the Northwest : A Digital Library Partnership in Oregon"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/748"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Corey A. Harper"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Nathan Georgitis"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Carol Hixson"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"PB Core--the Public Broadcasting Metadata Initiative: Progress Report"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"PB Core--the Public Broadcasting Metadata Initiative: Progress Report"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/749"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Alison M. While"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Alan Baker"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Marty Bloss"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Paul E. Burrows"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Efthimis N. Efthimiadis"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Marcia Brooks"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"David MacCarn"	P1545	"7"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Thom Shepard"	P1545	"8"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Cate Twohill"	P1545	"9"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Integrating Resource Metadata and Domain Markup in an NSDL Collection"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Integrating Resource Metadata and Domain Markup in an NSDL Collection"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/750"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Gregory M. Shreve"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Marcia Lei Zeng"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Using Dublin Core to Facilitate Cross-Collection Searches in an Enterprise Image Repository"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Using Dublin Core to Facilitate Cross-Collection Searches in an Enterprise Image Repository"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/751"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Kevin J. Hegg"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Andreas R. Knab"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Encoding Scheme Registration in the Government of Canada"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Encoding Scheme Registration in the Government of Canada"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/752"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Deane Henderson Zeeman"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Joy Bell"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Evolving Metadata Needs for an Institutional Repository: MIT's DSpace"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Evolving Metadata Needs for an Institutional Repository: MIT's DSpace"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/753"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Margret Branschofsky"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Rebecca Lubas"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"MacKenzie Smith"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Sarah Williams"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Generation of XML Records Across Multiple Metadata Standards"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Generation of XML Records Across Multiple Metadata Standards"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/754"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Kimberly S. Lightle"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Judy Ridgway"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Janet Kahkonen Smith"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Developing a Collection Registry for IMLS NLG Digital Collections"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Developing a Collection Registry for IMLS NLG Digital Collections"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/755"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Sarah L. Shreeves"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Timothy W. Cole"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Tracking Metadata Use for Digital Collections"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Tracking Metadata Use for Digital Collections"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/756"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Ellen Knutson"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Carol Palmer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Michael Twidale"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Study of 13-17th century Marathi manuscripts: author generated metadata and itsmapping with Dublin Core"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Study of 13-17th century Marathi manuscripts: author generated metadata and itsmapping with Dublin Core"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/757"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Shubhada Nagarkar"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Harsha Parekh"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"V.L. Manjul"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"A Preliminary Investigation of Metadata Description Mechanisms for Materials Science"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"A Preliminary Investigation of Metadata Description Mechanisms for Materials Science"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/758"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Laura M. Bartolo"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Cathy S. Lowe"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"That was then, this is now…: processes, services and the future of New Zealand government portals"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"That was then, this is now…: processes, services and the future of New Zealand government portals"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/759"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Sara Barham"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"University of Washington Early Buddhist Manuscripts Project in DSpace"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"University of Washington Early Buddhist Manuscripts Project in DSpace"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/760"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Kathleen Forsythe"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Alan Grosenheider"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Eileen Llona"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Jennifer Ward"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Automatically Categorizing Metadata Databases into a Categorization Scheme on a Large Scale Web Site"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Automatically Categorizing Metadata Databases into a Categorization Scheme on a Large Scale Web Site"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/761"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Barbara Richards"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Boris Lauser"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Johannes Keizer"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P2093	"Stephen Katz"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# CREATE
# LAST	Len	"Effective e-learning Content Discovery Using the Bath Profile"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1476	en:"Effective e-learning Content Discovery Using the Bath Profile"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/762"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
# LAST	P1433	Q68280420	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
#
# LAST	P2093	"Dan Noyes"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/26"
