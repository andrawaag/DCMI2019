# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2001

# %% [markdown]
# ## Create conference Item

# %%
year = "2001"
location = "Tokyo"

print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\"DC-"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"")
# Out:
# CREATE
# LAST	Len	"DC-2001"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2001: Tokyo"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"DC-2001"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2001"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68047734"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/24" ## Needs to be changed
location = "  Tokyo, Japan, 24-26 October 2001" ## Needs to be changed

print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2001 International Conference on Dublin Core and Metadata Applications, DC-2001 in   Tokyo, Japan, 24-26 October 2001"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Proceedings of the 2001 International Conference on Dublin Core and Metadata Applications, DC-2001 in   Tokyo, Japan, 24-26 October 2001"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P4745	Q68047734	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"

# %%
proceedingsQID = "Q68380204"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
i = 0
for article in table:
    i+=1
    if i == 1:
        continue
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"RDF Declarative Description (RDD): A Language for Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"RDF Declarative Description (RDD): A Language for Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/642"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Chutiporn Anutariya"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Vilas Wuwongse"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Kiyoshi Akama"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Ekawit Nantajeewarawat"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Multilingual Access to Dublin Core Metadata of ULIS Library"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Multilingual Access to Dublin Core Metadata of ULIS Library"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/643"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Danyang Wen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Tetsuo Sakaguchi"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Koichi Tabata"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"METAXPath"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"METAXPath"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/644"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Curtis E. Dyreson"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Michael H. Böhlen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Christian S. Jensen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"The Dublin Core and Metadata for Educational Resources"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"The Dublin Core and Metadata for Educational Resources"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/645"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Stuart A. Sutton"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Jon Mason"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A Framework for the Multi-modal Description of Learning Objects"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A Framework for the Multi-modal Description of Learning Objects"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/646"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Eva Heinrich"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Jisong Chen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Author-generated Dublin Core Metadata for Web Resources: A Baseline Study in an Organization"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Author-generated Dublin Core Metadata for Web Resources: A Baseline Study in an Organization"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/647"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Jane Greenberg"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Maria Cristina Pattuelli"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Bijan Parsia"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"W. Davenport Robertson"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Management of Environmental Information in the European Information and Observation Network (EIONET)"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Management of Environmental Information in the European Information and Observation Network (EIONET)"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/648"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Thomas Pick"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Hannu Saarenmaa"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Kirsti Lounamaa"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Collaborative Cataloguing of Moving Images and New Media Art Works"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Collaborative Cataloguing of Moving Images and New Media Art Works"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/649"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Simon Pockley"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Emily Cavanagh"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Metadata Mapping and Application Profiles. Approaches to providing the Cross-searching of Heterogeneous Resources in the EU Project Renardus"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Metadata Mapping and Application Profiles. Approaches to providing the Cross-searching of Heterogeneous Resources in the EU Project Renardus"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/650"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Heike Neuroth"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Traugott Koch"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A metadata framework to support scholarly communication"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A metadata framework to support scholarly communication"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/651"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Thomas Krichel"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Simeon M. Warner"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Mixing and Mapping Metadata to Provide Integrated Access to Digital Library Collections: An Activity Report"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Mixing and Mapping Metadata to Provide Integrated Access to Digital Library Collections: An Activity Report"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/652"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Karen Calhoun"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Tom Turner"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Meryl Brodsky"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"George Kozak"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Marty Kurth"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Fred Muratori"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"David Ruddy"	P1545	"7"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Sarah Young"	P1545	"8"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A Metadata Approach to Digital Preservation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A Metadata Approach to Digital Preservation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/653"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Maria Luisa Calanag"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Koichi Tabata"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"What Terms Does Your Metadata Use? Application Profiles as Machine-Understandable Narratives"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"What Terms Does Your Metadata Use? Application Profiles as Machine-Understandable Narratives"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/654"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Thomas Baker"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Makx Dekkers"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Rachel Heery"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Manjula Patel"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Gauri Salokhe"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"The ABC Ontology and Model"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"The ABC Ontology and Model"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/655"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Carl Lagoze"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Jane Hunter"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A Metadata Kernel for Electronic Permanence"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A Metadata Kernel for Electronic Permanence"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/656"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"John A. Kunze"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A Dublin Core Application Profile in the Agricultural Domain"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A Dublin Core Application Profile in the Agricultural Domain"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/657"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Irene Onyancha"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Johannes Keizer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Stephen Katz"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Design and Implementation of the National Institute of Environmental Health Sciences Dublin Core Metadata Schema"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Design and Implementation of the National Institute of Environmental Health Sciences Dublin Core Metadata Schema"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/658"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"W. Davenport Robertson"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Ellen M. Leadem"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Jed Dube"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Jane Greenberg"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Metadata Development for Digital Libraries and Museums – Taiwan's Experience"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Metadata Development for Digital Libraries and Museums – Taiwan's Experience"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/659"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Hsueh-hua Chen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Chao-chen Chen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A Multilingual Metadata Schema Registry Based on RDF Schema"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A Multilingual Metadata Schema Registry Based on RDF Schema"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/660"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Mitsuharu Nagamori"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Thomas Baker"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Tetsuo Sakaguchi"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Koichi Tabata"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Personalizing Information Spaces: A Metadata Based Approach"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Personalizing Information Spaces: A Metadata Based Approach"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/661"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"David L. Hicks"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Klaus Tochtermann"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Evaluation and Design Issues of Nordic DC Metadata Creation Tool"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Evaluation and Design Issues of Nordic DC Metadata Creation Tool"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/662"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Preben Hansen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"zetoc: a Dublin Core Based Current Awareness Service"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"zetoc: a Dublin Core Based Current Awareness Service"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/663"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Ann Apps"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Ross MacIntyre"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Metia–A Generalized Metadata Driven Framework for the Management and Distribution of ElectronicMedia"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Metia–A Generalized Metadata Driven Framework for the Management and Distribution of ElectronicMedia"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/664"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Patrick Stickler"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Qualified Dublin Core using RDF for Sci-Tech Journal Articles"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Qualified Dublin Core using RDF for Sci-Tech Journal Articles"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/665"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Thomas G. Habing"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Timothy W. Cole"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"William H. Mischo"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Metadata Interoperability and Meta-search on the Web"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Metadata Interoperability and Meta-search on the Web"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/666"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Enric Peig"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Jaime Delgado"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Ismael Pérez"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Interoperable Summary Description Model Using Dublin Core"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Interoperable Summary Description Model Using Dublin Core"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/667"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Do-Nyun Kim"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Young-Won Song"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A Metadata Case Study for the FRBR Model Based on Chinese Painting and Calligraphy at the National Palace Museum in Taipei"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A Metadata Case Study for the FRBR Model Based on Chinese Painting and Calligraphy at the National Palace Museum in Taipei"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/668"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Simon C. Lin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Ya-ning Chen"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Shu-jiun Chen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Yi-ting Chang"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Shai-lang Hu"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Adopting DC Metadata for Union Serial System of KERIS: It's Design and Implementation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Adopting DC Metadata for Union Serial System of KERIS: It's Design and Implementation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/669"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Yong Soon Kim"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Ji Won Lee"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Hyeong Yong Park"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A Metadata Application Profile for the German Virtual Library"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A Metadata Application Profile for the German Virtual Library"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/670"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Carola Wessel"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Heike Neuroth"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Design and Implementation of Metadata for Indian Fungi (Heterobasidiomycetes): Lessons From Library and Information Science Field"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Design and Implementation of Metadata for Indian Fungi (Heterobasidiomycetes): Lessons From Library and Information Science Field"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/671"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Shubhada Nagarkar"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Kanchanganga Gandhe"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Geoffrey Bowker"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Metadata for Evidence Based Medicine resources"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Metadata for Evidence Based Medicine resources"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/672"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Yukiko Sakai"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"A report on Dublin Core based research information service on mathematics"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"A report on Dublin Core based research information service on mathematics"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/673"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Kazuhiko Asou"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Takako Nakahara"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Takao Namiki"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Educational Information in the Web: Discussing the Metadata Requirements for a Web Service Guiding Citizens' Education"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Educational Information in the Web: Discussing the Metadata Requirements for a Web Service Guiding Citizens' Education"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/674"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Soile Hirvasniemi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Kai Öörni"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"The San Fernando Valley History Digital Project: a Collaborative Digital Project Between Local Historical Societies and a University Library"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"The San Fernando Valley History Digital Project: a Collaborative Digital Project Between Local Historical Societies and a University Library"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/675"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Mary S. Woodley"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Necessities on a Descriptive Level for Reusing Metadata Descriptions"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Necessities on a Descriptive Level for Reusing Metadata Descriptions"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/676"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Ohya Kazushi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Priority Control Mechanism managed by Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Priority Control Mechanism managed by Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/677"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Ray S. Atarashi"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Hiroyuki Ohno"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P2093	"Makoto Niimi"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"ISI's Implementation of Network Resources in Secondary Databases: Selection Criteria, Metadata, and Linking"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"ISI's Implementation of Network Resources in Secondary Databases: Selection Criteria, Metadata, and Linking"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/678"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	"Yasuki Kaneko"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Invited Paper: Effective Retrieval of Educational Resources by Using Learning Object Metadata for K-12 Schools in Japan"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Invited Paper: Effective Retrieval of Educational Resources by Using Learning Object Metadata for K-12 Schools in Japan"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/679"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Invited Paper: The Meaning of LOM and LOM Authoring Tool on HRD"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Invited Paper: The Meaning of LOM and LOM Authoring Tool on HRD"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/680"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Metadata in the UK"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Metadata in the UK"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/681"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"The use of Metadata in Denmark"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"The use of Metadata in Denmark"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/682"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Invited Paper: Between a Rock and a Hard Place: Dealing With NZGLS Development Issues"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Invited Paper: Between a Rock and a Hard Place: Dealing With NZGLS Development Issues"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/683"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Invited Abstract: Use of Dublin Core in a Portal Environment"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Invited Abstract: Use of Dublin Core in a Portal Environment"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/684"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Invited Paper: CSIS Clearinghouse for Academic Research Communities in Japan"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Invited Paper: CSIS Clearinghouse for Academic Research Communities in Japan"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/685"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Invited Paper: Geographic data clearinghouse activity in GSI"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Invited Paper: Geographic data clearinghouse activity in GSI"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/686"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# CREATE
# LAST	Len	"Invited Paper: Japan Metadata Profile (JMP) for Geographic Information Clearinghouses"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1476	en:"Invited Paper: Japan Metadata Profile (JMP) for Geographic Information Clearinghouses"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/687"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
# LAST	P1433	Q68380204	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/24"
