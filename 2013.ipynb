# %%
# !pip3 install bs4
# Out:
# Collecting bs4
#   Downloading https://files.pythonhosted.org/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# Collecting beautifulsoup4 (from bs4)
#   Using cached https://files.pythonhosted.org/packages/1a/b7/34eec2fe5a49718944e215fde81288eec1fa04638aa3fb57c1c6cd0f98c3/beautifulsoup4-4.8.0-py3-none-any.whl
# Collecting soupsieve>=1.2 (from beautifulsoup4->bs4)
#   Downloading https://files.pythonhosted.org/packages/0b/44/0474f2207fdd601bb25787671c81076333d2c80e6f97e92790f8887cf682/soupsieve-1.9.3-py2.py3-none-any.whl
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Stored in directory: /Users/andra/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.8.0 bs4-0.0.1 soupsieve-1.9.3

# %%
from bs4 import BeautifulSoup, SoupStrainer
import requests

# %% [markdown]
# # Proceedings 2013

# %% [markdown]
# ## Create conference Item

# %%
year = "2013"
location = "Lisbon"
print("CREATE")
print("LAST\tLen\t\"DC-"+year+"\"")     
print("LAST\tDen\t\"academic conference\"")
print("LAST\tAen\t\"DC-"+year+": "+location+"\"") 
print("LAST\tP31\tQ2020153\tS854\t\"https://www.dublincore.org/conferences/\"") 
print("LAST\tP31\tQ27968055\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP1813\ten:\""+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Needs to be changed
print("LAST\tP179\tQ68046465\tS854\t\"https://www.dublincore.org/conferences/\"")
print("LAST\tP856\t\"https://www.dublincore.org/conferences/"+year+"\"\tS854\t\"https://www.dublincore.org/conferences/\"") ## Need to be changed
# Out:
# CREATE
# LAST	Len	"DC-2013"
# LAST	Den	"academic conference"
# LAST	Aen	"DC-2013: Lisbon"
# LAST	P31	Q2020153	S854	"https://www.dublincore.org/conferences/"
# LAST	P31	Q27968055	S854	"https://www.dublincore.org/conferences/"
# LAST	P1813	en:"2013"	S854	"https://www.dublincore.org/conferences/"
# LAST	P179	Q68046465	S854	"https://www.dublincore.org/conferences/"
# LAST	P856	"https://www.dublincore.org/conferences/2013"	S854	"https://www.dublincore.org/conferences/"

# %%
conferenceQID = "Q68239149"

# %% [markdown]
# # Proceedings

# %%
referenceurl = "https://dcpapers.dublincore.org/pubs/issue/view/165" ## Needs to be changed
location = "Lisbon, Portugal, 2-6 September 2013" ## Needs to be changed
print("CREATE")
print("LAST\tLen\t\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"")  
print("LAST\tDen\t\"conference proceedings\"")
print("LAST\tP31\tQ1143604\tS854\t\""+referenceurl+"\"")
print("LAST\tP1476\ten:\"Proceedings of the "+year+" International Conference on Dublin Core and Metadata Applications, DC-"+year+" in "+location+"\"\tS854\t\""+referenceurl+"\"")
print("LAST\tP953\t\""+referenceurl+"\"")
print("LAST\tP4745\t"+conferenceQID+"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Proceedings of the 2013 International Conference on Dublin Core and Metadata Applications, DC-2013 in Lisbon, Portugal, 2-6 September 2013"
# LAST	Den	"conference proceedings"
# LAST	P31	Q1143604	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Proceedings of the 2013 International Conference on Dublin Core and Metadata Applications, DC-2013 in Lisbon, Portugal, 2-6 September 2013"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P4745	Q68239149	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"

# %%
proceedingsQID = "Q68239339"

# %% [markdown]
# ## Papers

# %%
import requests
from bs4 import BeautifulSoup, SoupStrainer

page = requests.get(referenceurl).text
soup = BeautifulSoup(page)

table = soup.findAll('td', {'class': 'tocArticleTitleAuthors'})
for article in table:
    title = article.find('div', {'class': 'tocTitle'})
    print("\nCREATE")
    print("LAST\tLen\t\""+title.text.strip().replace("\n", "")+"\"")
    print("LAST\tDen\t\"conference paper\"")
    print("LAST\tP31\tQ23927052\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1476\ten:\""+title.text.strip().replace("\n", "")+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP953\t\""+title.a["href"]+"\"\tS854\t\""+referenceurl+"\"")
    print("LAST\tP1433\t"+proceedingsQID+"\tS854\t\""+referenceurl+"\"") 
    print("")
    authors = article.find('div', {'class': 'tocAuthors'}).text.strip().split(",")
    seriesordinal = 0
    for author in authors:
        #print(author.strip())
        seriesordinal +=1
        print("LAST\tP2093\t\""+author.strip()+"\"\tP1545\t\""+str(seriesordinal)+"\"\tS854\t\""+referenceurl+"\"")
# Out:
# CREATE
# LAST	Len	"Introductions and Committees"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Introductions and Committees"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3668"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	""	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Provenance and Annotations for Linked Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Provenance and Annotations for Linked Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3669"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Kai Eckert"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"How Portable Are the Metadata Standards for Scientific Data? A Proposal for a Metadata                     Infrastructure"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"How Portable Are the Metadata Standards for Scientific Data? A Proposal for a Metadata                     Infrastructure"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3670"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Jian Qin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Kai Li"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Lessons Learned in Implementing the Extended Date/Time Format in a Large Digital                     Library"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Lessons Learned in Implementing the Extended Date/Time Format in a Large Digital                     Library"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3671"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Hannah Tarver"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Mark Phillips"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Towards the Representation of Chinese Traditional Music: A State of the Art Review                     of Music Metadata Standards"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Towards the Representation of Chinese Traditional Music: A State of the Art Review                     of Music Metadata Standards"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3672"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Mi Tian"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"György Fazekas"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Dawn Black"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Mark Sandler"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Maps and Gaps: Strategies for Vocabulary Design and Development"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Maps and Gaps: Strategies for Vocabulary Design and Development"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3673"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Diane Ileana Hillmann"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Gordon Dunsire"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Jon Phipps"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"A Method for the Development of Dublin Core Application Profiles (Me4DCAP V0.1):                     A Description"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"A Method for the Development of Dublin Core Application Profiles (Me4DCAP V0.1):                     A Description"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3674"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Mariana Curado Malta"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Ana Alice Baptista"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Find and Combine Vocabularies to Design Metadata Application Profiles using                     Schema Registries and LOD Resources"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Find and Combine Vocabularies to Design Metadata Application Profiles using                     Schema Registries and LOD Resources"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3675"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Tsunagu Honma"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Mitsuharu Nagamori"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Shigeo Sugimoto"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Achieving Interoperability between the CARARE Schema for Monuments and Sites and                     the Europeana Data Model"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Achieving Interoperability between the CARARE Schema for Monuments and Sites and                     the Europeana Data Model"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3676"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Antoine Isaac"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Valentine Charles"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Kate Fernie"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Costis Dallas"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Dimitris Gavrilis"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Stavros Angelis"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"With a Focused Intent: Evolution of DCMI as a Research Community"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"With a Focused Intent: Evolution of DCMI as a Research Community"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3677"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Jihee Beak"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Richard P. Smiraglia"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Metadata Capital in a Data Repository"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Metadata Capital in a Data Repository"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3678"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Jane Greenberg"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Shea Swauger"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Elena Feinstein"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"DC Metadata is Alive and Well (and has Influenced a New Standard for Education)"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"DC Metadata is Alive and Well (and has Influenced a New Standard for Education)"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3679"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Liddy Nevile"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Representation of the UNIMARC Bibliographic Data Format in Resource Description Framework"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Representation of the UNIMARC Bibliographic Data Format in Resource Description Framework"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3680"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Gordon Dunsire"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Mirna Willer"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Predrag Perožić"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Implementation of a Linked Open Data Solution for the Statistics Agency of                     Cantabria's Metadata and Data Bank"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Implementation of a Linked Open Data Solution for the Statistics Agency of                     Cantabria's Metadata and Data Bank"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3681"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Alejandro Villar Fernández"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Ana Santurtún Zarrabeitia"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Linked Data Driven Dynamic Web Services for Providing Multilingual Access to Diverse                     Japanese Humanities Databases"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Linked Data Driven Dynamic Web Services for Providing Multilingual Access to Diverse                     Japanese Humanities Databases"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3682"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Biligsaikhan Batjargal"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Takeo Kuyama"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Fuminori Kimura"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Akira Maeda"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Integration of Research Data and Research Data Links into Library Catalogues"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Integration of Research Data and Research Data Links into Library Catalogues"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3683"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Dominique Ritze"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Katarina Boland"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Collaborate, Automate, Prepare, Prioritize: Creating Metadata for Legacy Research                     Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Collaborate, Automate, Prepare, Prioritize: Creating Metadata for Legacy Research                     Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3684"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Inna Kouper"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Stacy R. Konkiel"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Jennifer A. Liss"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Juliet L. Hardesty"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Designing an Application Profile Using Qualified Dublin Core: A Case Study with                     Fracture Mechanics Datasets"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Designing an Application Profile Using Qualified Dublin Core: A Case Study with                     Fracture Mechanics Datasets"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3685"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"João Aguiar Castro"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Cristina Ribeiro"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"João Rocha da Silva"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Using Dublin Core Standard for the Metadata Description of Transport Statistics --                     Practical Experience from a Project Dedicated to the Set-Up of an Interlinked Statistics Portal"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Using Dublin Core Standard for the Metadata Description of Transport Statistics --                     Practical Experience from a Project Dedicated to the Set-Up of an Interlinked Statistics Portal"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3686"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Rene Kelpin"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Antje von Schmidt"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Michael Hepting"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Petra Kokus"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Alexandra Leipold"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Thorsten Schäfer"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"IN2N: Cross-institutional Authority Collaboration"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"IN2N: Cross-institutional Authority Collaboration"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3687"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Alexander Haffner"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Use of Authorities Open Data in the ARROW Rights Infrastructure"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Use of Authorities Open Data in the ARROW Rights Infrastructure"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3688"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Nuno Freire"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Markus Muhr"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Realising a Federation of Repositories of Reusable Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Realising a Federation of Repositories of Reusable Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3689"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Nikolaos Loutas"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Stijn Goedertier"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"João Rodrigues Frade"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Christophe Colas"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Michiel De Keyzer"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Debora Di Giacomo"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Makx Dekkers"	P1545	"7"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Vassilios Peristeras"	P1545	"8"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Reusing Textual Resources in Educational Assessment:  Adding Text Readability Metrics                     to Learning Metadata"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Reusing Textual Resources in Educational Assessment:  Adding Text Readability Metrics                     to Learning Metadata"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3690"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Muriel Foulonneau"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Eric Ras"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Elie Abou Zeid"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Talar Atéchian"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Approaches to Building Metadata for Data Curation"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Approaches to Building Metadata for Data Curation"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3691"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Hsueh-hua Chen"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Yu Lin"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Cynthia Chen"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"The Research of Open Conference Resources Organization based on RDA Description"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"The Research of Open Conference Resources Organization based on RDA Description"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3692"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Miaoling Chai"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Jiang Zhu"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Planning a Platform for Learning Linked Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Planning a Platform for Learning Linked Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3693"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Michael D. Crandall"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Joseph Tennis"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Stuart A. Sutton"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Thomas Baker"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"David Talley"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"ZBW Labs: Publish Projects as Linked Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"ZBW Labs: Publish Projects as Linked Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3694"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Joachim Neubert"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"OpenAIRE Guidelines for Data Archive, Literature Repository and CRIS Managers"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"OpenAIRE Guidelines for Data Archive, Literature Repository and CRIS Managers"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3695"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Pedro Príncipe"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Eloy Rodrigues"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Najla Rettberg"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Jochen Schirrwagen"	P1545	"4"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Mathias Loesch"	P1545	"5"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Mikael Karstensen Elbæk"	P1545	"6"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Lars Holm Nielsen"	P1545	"7"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Digital Humanities and Metadata: Linking the Past to the Digital Future"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Digital Humanities and Metadata: Linking the Past to the Digital Future"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3696"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Marina Morgan"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"M. J. Suhonos"	P1545	"2"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P2093	"Fangmin Wang"	P1545	"3"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# CREATE
# LAST	Len	"Using Metadata Standards to Improve IMF and National Data"
# LAST	Den	"conference paper"
# LAST	P31	Q23927052	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1476	en:"Using Metadata Standards to Improve IMF and National Data"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P953	"http://dcpapers.dublincore.org/pubs/article/view/3697"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
# LAST	P1433	Q68239339	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
#
# LAST	P2093	"Nalini Umashankar"	P1545	"1"	S854	"https://dcpapers.dublincore.org/pubs/issue/view/165"
